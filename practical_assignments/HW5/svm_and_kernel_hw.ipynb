# %% [markdown]
# <div align="center">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/a/a3/University_of_Isfahan-Logo.png" width="100" height="100">
# </div>
#
# <div dir="rtl" align="center">
#   <h1> </h1>
#   <h4> Isfahan University - Computer Science </h4>
#   <h4 style="color:#3399FF"> Machine Learning </h4>
#   <h5> May, 2024 </h5>
#   <hr>
#   <h2 style="color:#006633"> <strong>HW5: Support Vector Machine & Kernel Method</strong> </h2>
#   <hr>
# </div>
#
# <h3> Your Student ID:  </h3>
# <h3> Your Name:  </h3>
# <hr>

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.datasets import make_blobs, make_circles

# %% [markdown]
# ### Generate separable data (don't change random_state)

# %%
X, y = make_blobs(n_samples=24, n_features=2, centers=2, cluster_std=2.4, random_state=48)

colormap = np.array(['r', 'b'])

fig, ax = plt.subplots(figsize=(4, 4))

_ = ax.scatter(X[:, 0], X[:, 1], c=colormap[y], edgecolors="k", s=70, linewidth=2, alpha=0.6)

_ = ax.set_xlabel("$X_1$")
_ = ax.set_ylabel("$X_2$")

# %% [markdown]
# ### Questions

# %% [markdown]
# <strong style="color:red "> Q1. </strong> plot points on 3D. Consider the following point:
#
# - set figsize to (4, 4)
# - set `c` to colormaps
# - set edgecolors to `k`
# - set xlabel to X_1
# - set ylabel to X_2
# - set zlabel to y

# %% [markdown]
# <strong style="color:red "> Q2. </strong> `Train`, `Predict` and calculate `accuracy` of `X` by `SVM`. Consider the following point:
#
# - set kernel to `linear`
# - predict of `X` to `y_pred` variable
# - for calculate accuracy, you can find it in `sklearn` library.

# %% [markdown]
# <strong style="color:red "> Q3. </strong> Plot hypothesis and support vectors of `SVM` model. Consider the following point:
#
# - for legend, set `loc` to `center right` and `bbox_to_anchor` to `(1.6, 0.8)`
# - the output of the `plot` should be similar to the output of the following code blocks.

# %% [markdown]
# #### make non-separable data (don't change random_state)

# %%
X, y = make_blobs(n_samples=60, n_features=2, centers=2, cluster_std=7, random_state=48)

fig, ax = plt.subplots(figsize=(4, 4))

_ = ax.scatter(X[:, 0], X[:, 1], c=colormap[y], edgecolors="k", s=70, linewidth=2, alpha=0.6)

_ = ax.set_xlabel("$X_1$")
_ = ax.set_ylabel("$X_2$")

# %% [markdown]
# <strong style="color:red "> Q4. </strong> construct `three SVM`. `Train` and `Evaluate` all of them and consider the following point:
#
# - set kernel to `linear`
# - for first Model, set `C` to `0.001`
# - for Second Model, set `C` to `0.01`
# - for Third Model, set `C` to `1`
# - predict of `X` to `y_pred` variable

# %%
# Out:
# Model 1	 0.7333333333333333
# Model 2	 0.8166666666666667
# Model 3	 0.8

# %% [markdown]
# <strong style="color:red "> Q5. </strong> plot `three SVM` hypothesis and their support vectors. Consider the following point:
#
# - set figsize to (12, 4)
# - the output of the `plot` should be similar to the output of the following code blocks.

# %% [markdown]
# #### Polynomial Kernel in SVM (don't change random_state)

# %%
X, y = make_circles(n_samples=500, noise=0.1, factor=0.2, random_state=48)

fig, ax = plt.subplots(figsize=(4, 4))

_ = ax.scatter(X[:, 0], X[:, 1], c=colormap[y], edgecolors="k", s=70, linewidth=2, alpha=0.6)

_ = ax.set_xlabel("$X_1$")
_ = ax.set_ylabel("$X_2$")

# %% [markdown]
# <strong style="color:red "> Q6. </strong> `Train`, `Predict` and `Evaluate` of `X` by `SVM`. Consider the following point:
#
# - set kernel to `linear`

# %% [markdown]
# <strong style="color:red "> Q7. </strong> `Train`, `Predict` and `Evaluate` of `X` by `SVM`. Consider the following point:
#
# - set kernel to `rbf`

# %% [markdown]
# <strong style="color:red "> Q8. </strong> Use `PolynomialFeatures` as a kernel and applied to `SVM` model, then evaluate model. Consider the following point:
#
# - do it this work by `Pipeline`
# - set `kernel` to `linear`
# - set `degree` to 2
# - you can find this module in `sklearn` library.

# %%
# Out:
# Pipeline(steps=[('poly_features', PolynomialFeatures()),
#                 ('svc', SVC(kernel='linear'))])

# %% [markdown]
# <strong style="color:red "> Q9. </strong> Do the following steps in order:
#
# - load `iris` data from `sklearn.datasets` into X, y
# - create `param_grid` dictionary s.t.
#
#         C: [0.001, 0.01, 1]
#         kernel: ["rbf", "poly"]
#         poly_features__degree: [1, 2, 3]
#
# - create Pipeline with `PolynomialFeatures` and `SVC`, respectively.
# - Give this pipeline to `GridSearchCV`
# - set `cv` to 5
# - finally, report best model and its info

# %%
# Out:
# {'memory': None, 'steps': [('poly_features', PolynomialFeatures(degree=1)), ('svc', SVC(C=1, kernel='poly'))], 'verbose': False, 'poly_features': PolynomialFeatures(degree=1), 'svc': SVC(C=1, kernel='poly'), 'poly_features__degree': 1, 'poly_features__include_bias': True, 'poly_features__interaction_only': False, 'poly_features__order': 'C', 'svc__C': 1, 'svc__break_ties': False, 'svc__cache_size': 200, 'svc__class_weight': None, 'svc__coef0': 0.0, 'svc__decision_function_shape': 'ovr', 'svc__degree': 3, 'svc__gamma': 'scale', 'svc__kernel': 'poly', 'svc__max_iter': -1, 'svc__probability': False, 'svc__random_state': None, 'svc__shrinking': True, 'svc__tol': 0.001, 'svc__verbose': False}
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('poly_features', PolynomialFeatures()),
#                                        ('svc', SVC())]),
#              param_grid={'poly_features__degree': [1, 2, 3],
#                          'svc__C': [0.001, 0.01, 1],
# ...
